# %%
# You must run this cell to install dependency
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np

# %%
def hash_function(s, hash):
    return
def insert(s, hash):
    pass
def create_from_array(arr,hash):
    for i in arr:
      insert(i,hash)
    return hash

# %%
print('===================Test01==============================')
arr1 = ['gemini', 'leo', 'pisces', 'cancer', 'libra', 'Scorpio']
new_table1=[0]*len(arr1)
result1 = create_from_array(arr1,new_table1)
print(result1) #This should print ['leo','libra','Scorpio','cancer','gemini','pisces']
unittest.output_test(result1, ['leo','libra','Scorpio','cancer','gemini','pisces'])

print('===================Test02==============================')
arr2 = ['owl', 'snail', 'bird', 'fish']
new_table2=[0]*len(arr2)
result2 = create_from_array(arr2,new_table2)
print(result2) #This should print ['bird','snail','owl','fish']
unittest.output_test(result2, ['bird','snail','owl','fish'])
