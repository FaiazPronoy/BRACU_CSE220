# %%
class Node:
  def __init__(elem, next):
    # self.key = key
    self.elem = elem
    self.next = next

# %%
def hashing(arr):
  hash_table = [None]*size(arr)

  for elem in arr:
    idx = elem % len(hash_table)
    if hash_table[idx]==None:
      hahs_table[idx] = Node(elem, None)

    else:
      head = hash_table[idx]
      new_node = Node(elem, head)
      hash_table[idx] = new_node

# %%
def search(int key):
  idx = key % len(hash_table)
  head =  hash_table[idx]

  while head!=None:
    if haed.elem == key:
      return True
    head = head.next

  return False
