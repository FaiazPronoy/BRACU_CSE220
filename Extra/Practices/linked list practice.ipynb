# %%
class Node:
  def __init__(self, e, n):
    self.elem = e
    self.next = n
def createlist(arr):
  head = Node(arr[0], None)
  tail = head

  for i in range(1, len(arr)):
    head2 = Node(arr[i], None)
    tail.next = head2
    tail = tail.next
  return head

def iterate(head):
  counter = 0

  while head != None:
    print(head.elem)
    head = head.next
    counter += 1


def elem_at(head, idx):
  temp = head
  temp_idx = 0

  while temp != None:
    if temp_idx == idx:
       return temp
    else:
      temp_idx += 1
      temp = temp.next

def count(head):
  counter = 0
  while head != None:
    head = head.next
    counter += 1
  return head





arr = [1, 2, 3, 4, 5]
head = createlist(arr)
# Out:
# 3

# %%
def insert(head, elem, idx):
  total_nodes = count(head)
  if idx == 0:
    new_head = Node(elem, head)
    head = new_head
  return head

head = insert(head, 15, 0)
