# %%
class BTNode:
  #Write a constructor

# %%
def inorder(root):
  if root == None:
    return

  inorder(root.left)
  print(root.elem, end = ' ')
  inorder(root.right)

# %%
def tree_construction(arr, i = 1):
  if i>=len(arr) or arr[i] == None:
    return None

  p = BTNode(arr[i])
  p.left = tree_construction(arr, 2*i)
  p.right = tree_construction(arr, 2*i+1)
  return p

# %%
def keyCount(root,key):
  #Write your code

# %%
#Driver Code
arr=[None,3,2,8,3,3,3,8,6,2,3,7]
root=tree_construction(arr)
print(keyCount(root, 3))

# %%
def sum(n):
  #Write your code

# %%
#Driver code
value=sum(4)
print(value)
